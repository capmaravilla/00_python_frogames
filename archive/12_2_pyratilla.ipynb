# %%
import pandas as pd

hp_df = pd.read_csv(
    "./characters-hp.csv", sep=";", encoding="Windows-1252"
)  # Added sep and encoding arguments
hp_df
# Out:
#       Id                                     Name  Gender  \
# 0      1                       Harry James Potter    Male
# 1      2                    Ronald Bilius Weasley    Male
# 2      3                    Hermione Jean Granger  Female
# 3      4  Albus Percival Wulfric Brian Dumbledore    Male
# 4      5                            Rubeus Hagrid    Male
# ..   ...                                      ...     ...
# 135  136                 Wilhelmina Grubbly-Plank  Female
# 136  137                          Fenrir Greyback    Male
# 137  138                      Gellert Grindelwald    Male
# 138  139                                    Dobby    Male
# 139  140                                 Kreacher    Male
#
#                                                    Job       House  \
# 0                                              Student  Gryffindor
# 1                                              Student  Gryffindor
# ...

# %% [markdown]
# Prueba 1: Calcula el total de observaciones del csv que has guardado en la variable hp_df

# %%
observaciones = hp_df.shape[0]
observaciones
# Out:
# 140

# %% [markdown]
# Prueba 2: Da la instrucción para visualizar las 10 primeras observaciones del dataframe

# %%
hp_df.head(10)
# Out:
#    Id                                     Name  Gender  \
# 0   1                       Harry James Potter    Male
# 1   2                    Ronald Bilius Weasley    Male
# 2   3                    Hermione Jean Granger  Female
# 3   4  Albus Percival Wulfric Brian Dumbledore    Male
# 4   5                            Rubeus Hagrid    Male
# 5   6                       Neville Longbottom    Male
# 6   7                             Fred Weasley    Male
# 7   8                           George Weasley    Male
# 8   9            Ginevra (Ginny) Molly Weasley  Female
# 9  10                              Dean Thomas    Male
#
#                                                  Job       House  \
# 0                                            Student  Gryffindor
# 1                                            Student  Gryffindor
# 2                                            Student  Gryffindor
# 3                                         Headmaster  Gryffindor
# ...

# %% [markdown]
# Prueba 3: Averigua el índice de la columna llamada Id. Después, guarda en la variable hp_df todas las filas y todas las columnas salvo la columna que lleva por nombre Id. En otras palabras, elimina la columna que lleva por nombre Id del dataframe original haciendo uso del método .columns()

# %%
hp_df = hp_df.drop(columns=["Id"])
hp_df
# Out:
#                                         Name  Gender  \
# 0                         Harry James Potter    Male
# 1                      Ronald Bilius Weasley    Male
# 2                      Hermione Jean Granger  Female
# 3    Albus Percival Wulfric Brian Dumbledore    Male
# 4                              Rubeus Hagrid    Male
# ..                                       ...     ...
# 135                 Wilhelmina Grubbly-Plank  Female
# 136                          Fenrir Greyback    Male
# 137                      Gellert Grindelwald    Male
# 138                                    Dobby    Male
# 139                                 Kreacher    Male
#
#                                                    Job       House  \
# 0                                              Student  Gryffindor
# 1                                              Student  Gryffindor
# 2                                              Student  Gryffindor
# ...

# %% [markdown]
# Prueba 4: Tras el cambio, ¿de cuántas variables consta el dataframe hp_df?

# %%
variables = hp_df.shape[1]
variables
# Out:
# 14

# %% [markdown]
# Prueba 5: Di el valor de la variable Species para el personaje llamado Dobby sin usar el método .query()

# %%
hp_df.loc[138, "Species"]
# Out:
# 'House elf'

# %% [markdown]
# Prueba 6: Usa el método .query() para obtener únicamente las observaciones cuyo valor de la variable Job es Student y guarda este dataframe filtrado en la variable hp_students

# %%
hp_students = hp_df.query("Job == 'Student'")
hp_students.head()
# Out:
#                     Name  Gender      Job       House  \
# 0     Harry James Potter    Male  Student  Gryffindor
# 1  Ronald Bilius Weasley    Male  Student  Gryffindor
# 2  Hermione Jean Granger  Female  Student  Gryffindor
# 5     Neville Longbottom    Male  Student  Gryffindor
# 6           Fred Weasley    Male  Student  Gryffindor
#
#                                  Wand              Patronus Species  \
# 0         11"  Holly  phoenix feather                  Stag   Human
# 1          12" Ash unicorn tail hair   Jack Russell terrier   Human
# 2  10¾"  vine wood dragon heartstring                 Otter   Human
# 5             13" Cherry unicorn hair         Non-corporeal   Human
# 6                             Unknown               Unknown   Human
#
#   Blood status Hair colour    Eye colour  \
# 0   Half-blood       Black  Bright green
# 1   Pure-blood         Red          Blue
# 2  Muggle-born       Brown         Brown
# 5   Pure-blood       Blond           NaN
# ...

# %% [markdown]
# Prueba 7: Fíjate que los nombres de las filas del dataframe hp_students siguen siendo los originales. Renombra las filas para que vayan del 1 al número total de observaciones que haya en hp_students. PISTA: Para acceder a los índices del dataframe puedes llamar al atributo index. Se trata de que sustituyas el original por una lista que contega como entradas los números que van del 1 al número total de observaciones que tiene el dataframe hp_students

# %%
hp_students.insert(
    loc=0,
    column="ID",
    value=[x for x in range(1, hp_students.shape[0] + 1)],
)
hp_students = hp_students.set_index("ID")
hp_students.index.names = [None]

hp_students.head()
# Out:
#                     Name  Gender      Job       House  \
# 1     Harry James Potter    Male  Student  Gryffindor
# 2  Ronald Bilius Weasley    Male  Student  Gryffindor
# 3  Hermione Jean Granger  Female  Student  Gryffindor
# 4     Neville Longbottom    Male  Student  Gryffindor
# 5           Fred Weasley    Male  Student  Gryffindor
#
#                                  Wand              Patronus Species  \
# 1         11"  Holly  phoenix feather                  Stag   Human
# 2          12" Ash unicorn tail hair   Jack Russell terrier   Human
# 3  10¾"  vine wood dragon heartstring                 Otter   Human
# 4             13" Cherry unicorn hair         Non-corporeal   Human
# 5                             Unknown               Unknown   Human
#
#   Blood status Hair colour    Eye colour  \
# 1   Half-blood       Black  Bright green
# 2   Pure-blood         Red          Blue
# 3  Muggle-born       Brown         Brown
# 4   Pure-blood       Blond           NaN
# ...

# %% [markdown]
# Prueba 8: ¿Qué proporción de estudiantes hay? La proporción se calcula como el número de estudiantes entre el número total de observaciones.

# %%
students_proportion = hp_students.shape[0] / hp_df.shape[0]
students_proportion
# Out:
# 0.37142857142857144

# %% [markdown]
# Prueba 9: ¿Cuál es el valor de Hair colour para la observación 30 de hp_students? Calcúlalo usando el método .loc[]

# %%
hp_students.loc[30, "Hair colour"]
# Out:
# nan

# %% [markdown]
# Prueba 10: Obtén la cantidad de colores diferentes que hay para la variable Eye colour en el dataframe hp_students. Recuerda que nan no es un color. ¿Cuántos estudiantes no tienen un valor para la variable Eye colour?

# %%
eye_colour = hp_students["Eye colour"].dropna().unique()
eye_colour
# Out:
# array(['Bright green', 'Blue', 'Brown', 'Bright brown', 'Dark',
#        'Pale silvery', 'Grey', 'Black', 'Scarlet\xa0', 'Variable'],
#       dtype=object)
